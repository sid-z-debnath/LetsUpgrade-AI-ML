# %% [markdown]
# __Problem Statement:__ A large company named XYZ, employs, at any given point of time, around 4000 employees. However, every year, around 15% of its employees leave the company and need to be replaced with the talent pool available in the job market. The management believes that this level of attrition (employees leaving, either on their own or because they got fired) is bad for the company, because of the following reasons -
#
# ● A sizable department has to be maintained, for the purposes of recruiting new talent<br/>
# ● More often than not, the new employees have to be trained for the job and/or given time to
# acclimatize themselves to the company<br/>
# ● Hence, the management has contracted an HR analytics firm to understand what factors they
# should focus on, in order to curb attrition.<br/>
# ● In other words, they want to know what changes they should make to their workplace, in order to
# get most of their employees to stay.<br/>
# ● Also, they want to know which of these variables is most important and needs to be addressed
# right away.<br/>
#
# Since you are one of the star analysts at the firm, this project has been given to you.
#
# Goal of the case study You are required to model the probability of attrition. The results thus obtained will be used by the management to understand what changes they should make to their workplace, in order to get most of their employees to stay.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#load data
data = pd.read_csv('general_data.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                11              8
# 1                 0.0      Y                23              8
# 2                 1.0      Y                15              8
# 3                 3.0      Y                11              8
# 4                 4.0      Y                12              8
#
#    StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0               1.0                      6               1
# 1                 1               6.0                      3               5
# 2                 3               5.0                      2               5
# 3                 3              13.0                      5               8
# 4                 2               9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        1                     4
# 2                        0                     3
# 3                        7                     5
# 4                        0                     4
#
# [5 rows x 24 columns]

# %%
data = data.dropna()
data = data.drop_duplicates()

# %%
data.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4382.000000       4382.000000  4382.000000         4382.0  4382.000000
# mean     36.933364          9.198996     2.912369            1.0  2207.804884
# std       9.137272          8.105396     1.024728            0.0  1271.688783
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1108.250000
# 50%      36.000000          7.000000     3.000000            1.0  2208.500000
# 75%      43.000000         14.000000     4.000000            1.0  3308.750000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4382.000000    4382.000000         4382.000000        4382.000000
# mean      2.063898   65061.702419            2.693291          15.210634
# std       1.106115   47142.310175            2.497832           3.663007
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
# 50%       2.000000   49190.000000            2.000000          14.000000
# 75%       3.000000   83790.000000            4.000000          18.000000
# max       5.000000  199990.000000            9.000000          25.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         4382.0       4382.000000        4382.000000
# mean             8.0          0.794614          11.290278
# std              0.0          0.852397           7.785717
# min              8.0          0.000000           0.000000
# 25%              8.0          0.000000           6.000000
# 50%              8.0          1.000000          10.000000
# 75%              8.0          1.000000          15.000000
# max              8.0          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count            4382.000000     4382.000000              4382.000000
# mean                2.798266        7.010497                 2.191693
# std                 1.289402        6.129351                 3.224994
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        3.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count           4382.000000
# mean               4.126198
# std                3.569674
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000

# %%
len(data)
# Out:
# 4382

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %%
import seaborn as sns

# %%
plt.bar()

# %%
data[data.Attrition == 'Yes']['BusinessTravel'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['BusinessTravel'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'Yes']['Department'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['Department'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'Yes']['EducationField'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['EducationField'].value_counts().plot(kind='bar');

# %% [markdown]
# **Observation:** Employees who studied Human Resources are more likely to leave the company

# %%
data[data.Attrition == 'Yes']['Gender'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['Gender'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'Yes']['JobRole'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['JobRole'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'Yes']['MaritalStatus'].value_counts().plot(kind='bar');

# %%
data[data.Attrition == 'No']['MaritalStatus'].value_counts().plot(kind='bar');

# %% [markdown]
# **Observation:** Employees with marital status as Divorced are less likely to leave the company

# %%
df.boxplot(['Age'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['Age'].describe()
# Out:
# count    10.000000
# mean     35.200000
# std      10.239358
# min      19.000000
# 25%      29.500000
# 50%      34.500000
# 75%      39.000000
# max      58.000000
# Name: Age, dtype: float64

# %%
df[df['Attrition'] == 'No']['Age'].describe()
# Out:
# count    90.000000
# mean     36.822222
# std       9.196455
# min      20.000000
# 25%      29.250000
# 50%      36.000000
# 75%      42.750000
# max      60.000000
# Name: Age, dtype: float64

# %%
df[df['Attrition'] == 'No']['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        70
# Travel_Frequently    11
# Non-Travel            9
# Name: BusinessTravel, dtype: int64

# %%
df[df['Attrition'] == 'Yes']['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        8
# Travel_Frequently    2
# Name: BusinessTravel, dtype: int64

# %%
df[df['Attrition'] == 'Yes']['Gender'].value_counts()
# Out:
# Male      6
# Female    4
# Name: Gender, dtype: int64

# %%
df[df['Attrition'] == 'No']['Gender'].value_counts()
# Out:
# Male      59
# Female    31
# Name: Gender, dtype: int64

# %%
df.boxplot(['DistanceFromHome'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['DistanceFromHome'].describe()
# Out:
# count    10.000000
# mean      5.300000
# std       5.888784
# min       1.000000
# 25%       1.250000
# 50%       2.000000
# 75%       7.750000
# max      16.000000
# Name: DistanceFromHome, dtype: float64

# %%
df[df['Attrition'] == 'No']['DistanceFromHome'].describe()
# Out:
# count    90.000000
# mean     11.277778
# std       8.564400
# min       1.000000
# 25%       4.000000
# 50%      10.000000
# 75%      17.000000
# max      29.000000
# Name: DistanceFromHome, dtype: float64

# %% [markdown]
# __Hypothesis Statement 1:__ The average distance from home of the employees who left the company is 5 unit.

# %%
df.boxplot(['MonthlyIncome'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['MonthlyIncome'].describe()
# Out:
# count        10.000000
# mean      74437.000000
# std       57902.884797
# min       24130.000000
# 25%       36775.000000
# 50%       43345.000000
# 75%      114732.500000
# max      173990.000000
# Name: MonthlyIncome, dtype: float64

# %%
df[df['Attrition'] == 'No']['MonthlyIncome'].describe()
# Out:
# count        90.000000
# mean      70027.222222
# std       45944.255868
# min       20080.000000
# 25%       33372.500000
# 50%       53980.000000
# 75%      101262.500000
# max      199260.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# __Hypothesis Statement 2:__ The average monthly salary of the employees who left the company is 75000.

# %%
df.boxplot(['NumCompaniesWorked'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['NumCompaniesWorked'].describe()
# Out:
# count    10.00000
# mean      3.10000
# std       2.18327
# min       1.00000
# 25%       1.00000
# 50%       3.00000
# 75%       4.00000
# max       7.00000
# Name: NumCompaniesWorked, dtype: float64

# %%
df[df['Attrition'] == 'No']['NumCompaniesWorked'].describe()
# Out:
# count    90.000000
# mean      2.788889
# std       2.598593
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       4.000000
# max       9.000000
# Name: NumCompaniesWorked, dtype: float64

# %% [markdown]
# __Hypothesis Statement 3:__ The average number of companies where the employees who left the company previously worked is greater than equal to 3.

# %%
df.boxplot(['PercentSalaryHike'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['PercentSalaryHike'].describe()
# Out:
# count    10.000000
# mean     15.600000
# std       3.134042
# min      12.000000
# 25%      13.250000
# 50%      15.500000
# 75%      16.750000
# max      23.000000
# Name: PercentSalaryHike, dtype: float64

# %%
df[df['Attrition'] == 'No']['PercentSalaryHike'].describe()
# Out:
# count    90.000000
# mean     15.844444
# std       3.879972
# min      11.000000
# 25%      13.000000
# 50%      15.000000
# 75%      18.750000
# max      25.000000
# Name: PercentSalaryHike, dtype: float64

# %% [markdown]
# __Hypothesis Statement 4:__ The average percent salary hike of the employees who left the company is less than equal to 15.5.

# %%
df.boxplot(['StockOptionLevel'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['StockOptionLevel'].describe()
# Out:
# count    10.000000
# mean      1.000000
# std       0.666667
# min       0.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       2.000000
# Name: StockOptionLevel, dtype: float64

# %%
df[df['Attrition'] == 'No']['StockOptionLevel'].hist();

# %% [markdown]
# __Hypothesis Statement 5:__ The average Stock Option Level of the employees who left the company is 1.

# %%
df.boxplot(['TotalWorkingYears'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['TotalWorkingYears'].describe()
# Out:
# count    10.000000
# mean     10.600000
# std      11.862171
# min       1.000000
# 25%       2.250000
# 50%       8.500000
# 75%      11.750000
# max      40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
df[df['Attrition'] == 'No']['TotalWorkingYears'].describe()
# Out:
# count    90.000000
# mean     11.166667
# std       8.049356
# min       1.000000
# 25%       6.000000
# 50%       9.500000
# 75%      12.750000
# max      37.000000
# Name: TotalWorkingYears, dtype: float64

# %% [markdown]
# __Hypothesis Statement 6:__ The average number of working years of the employees who left the company is less than equal to 10.

# %%
df.boxplot(['TrainingTimesLastYear'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['TrainingTimesLastYear'].describe()
# Out:
# count    10.000000
# mean      2.000000
# std       1.154701
# min       0.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       3.000000
# Name: TrainingTimesLastYear, dtype: float64

# %%
df[df['Attrition'] == 'No']['TrainingTimesLastYear'].describe()
# Out:
# count    90.000000
# mean      2.833333
# std       1.359527
# min       0.000000
# 25%       2.000000
# 50%       2.500000
# 75%       3.000000
# max       6.000000
# Name: TrainingTimesLastYear, dtype: float64

# %% [markdown]
# __Hypothesis Statement 7:__ The average number of trainings the employees who left the company attended last year is 2.

# %%
df.boxplot(['YearsAtCompany'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['YearsAtCompany'].describe()
# Out:
# count    10.000000
# mean      6.000000
# std      12.101423
# min       1.000000
# 25%       1.000000
# 50%       1.500000
# 75%       3.500000
# max      40.000000
# Name: YearsAtCompany, dtype: float64

# %%
df[df['Attrition'] == 'No']['YearsAtCompany'].hist();

# %% [markdown]
# __Hypothesis Statement 8:__ The average number of years the employees who left the company were with the company is less than equal to 5.

# %%
df.boxplot(['YearsSinceLastPromotion'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['YearsSinceLastPromotion'].describe()
# Out:
# count    10.000000
# mean      1.900000
# std       4.677369
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.500000
# max      15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %% [markdown]
# __Hypothesis Statement 9:__ The average number of years since the last promotion of the employees who left the company is less than equal to 2.

# %%
df.boxplot(['YearsWithCurrManager'], by='Attrition', figsize=(5, 8));

# %%
df[df['Attrition'] == 'Yes']['YearsWithCurrManager'].describe()
# Out:
# count    10.000000
# mean      2.000000
# std       2.624669
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.750000
# max       7.000000
# Name: YearsWithCurrManager, dtype: float64

# %% [markdown]
# __Hypothesis Statement 10:__ The average number of years the employees who left the company were with their current managers is less than equal to 2.

# %% [markdown]
# **Conclusion:** From the above analysis it can be inferred that less distance from home, less number of promotions, less work experience are some of the important reasons of attrition.
